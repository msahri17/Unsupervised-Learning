# %% [markdown]
# <hr>

# %% [markdown]
# ## 01| Dataset Information

# %% [markdown]
# Dataset yang digunakan adalah dataset <a href='https://www.kaggle.com/arjunbhasin2013/ccdata'>Credit Card</a>. Dataset terdiri perilaku penggunaan kartu kredit dari 9000 pemegang kartu kredit. Dataset ini digunakan untuk membangun segmentasi pelanggan untuk menentukan strategi <i>marketing</i>.
#
# __Dataset Information (languange):__
#
# * CUSTID : Identification of Credit Card holder (Categorical)
# * BALANCE : Balance amount left in their account to make purchases
# * BALANCE_FREQUENCY : How frequently the Balance is updated, score between 0 and 1 (1 = frequently updated, 0 = not frequently updated)
# * PURCHASES : Amount of purchases made from account
# * ONEOFF_PURCHASES : Maximum purchase amount done in one-go
# * INSTALLMENTS_PURCHASES : Amount of purchase done in installment
# * CASH_ADVANCE : Cash in advance given by the user
# * PURCHASES_FREQUENCY : How frequently the Purchases are being made, score between 0 and 1 (1 = frequently purchased, 0 = not frequently purchased)
# * ONEOFF_PURCHASES_FREQUENCY : How frequently Purchases are happening in one-go (1 = frequently purchased, 0 = not frequently purchased)
# * PURCHASES_INSTALLMENTS_FREQUENCY : How frequently purchases in installments are being done (1 = frequently done, 0 = not frequently done)
# * CASH_ADVANCE_FREQUENCY : How frequently the cash in advance being paid
# * CASH_ADVANCE_TRX : Number of Transactions made with "Cash in Advanced"
# * PURCHASES_TRX : Numbe of purchase transactions made
# * CREDIT_LIMIT : Limit of Credit Card for user
# * PAYMENTS : Amount of Payment done by user
# * MINIMUM_PAYMENTS : Minimum amount of payments made by user
# * PRC_FULL_PAYMENT : Percent of full payment paid by user
# * TENURE : Tenure of credit card service for user

# %% [markdown]
# __Dataset Information (bahasa):__
#
# * CUSTID : Identitas Pemegang Kartu Kredit (Kategoris)
# * BALANCE : Jumlah saldo yang tersisa di akun mereka untuk melakukan pembelian
# * BALANCE_FREQUENCY : Seberapa sering Saldo diperbarui, skor antara 0 dan 1 (1 = sering diperbarui, 0 = tidak sering diperbarui)
# * PURCHASES : Jumlah pembelian yang dilakukan dari akun
# * ONEOFF_PURCHASES : Jumlah pembelian maksimum dilakukan dalam sekali sekali jalan
# * INSTALLMENTS_PURCHASES : Jumlah pembelian yang dilakukan secara cicilan
# * CASH_ADVANCE : Uang tunai di muka yang diberikan oleh pengguna
# * PURCHASES_FREQUENCY : Seberapa sering Pembelian dilakukan, skor antara 0 dan 1 (1 = sering dibeli, 0 = tidak sering dibeli)
# * ONEOFF_PURCHASES_FREQUENCY : Seberapa sering Pembelian terjadi dalam sekali jalan (1 = sering dibeli, 0 = tidak sering dibeli)
# * PURCHASES_INSTALLMENTS_FREQUENCY : Seberapa sering pembelian secara mencicil dilakukan (1 = sering dilakukan, 0 = tidak sering dilakukan)
# * CASH_ADVANCE_FREQUENCY : Seberapa sering pembayaran tunai di muka
# * CASH_ADVANCE_TRX : Jumlah Transaksi yang dilakukan dengan "Cash in Advanced"
# * PURCHASES_TRX : Jumlah transaksi pembelian yang dilakukan
# * CREDIT_LIMIT : Batas Kartu Kredit untuk pengguna
# * PAYMENTS : Jumlah Pembayaran yang dilakukan oleh pengguna
# * MINIMUM_PAYMENTS : Jumlah pembayaran minimum yang dilakukan oleh pengguna
# * PRC_FULL_PAYMENT : Persentase pembayaran penuh yang dibayarkan oleh pengguna
# * TENURE : Jangka waktu layanan kartu kredit untuk pengguna

# %% [markdown]
# <hr>

# %% [markdown]
# ## 02| Profiling and Understanding Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Loading dataset
df = pd.read_csv('credit-card-data.csv', index_col  = 'CUST_ID')
df.head(5)
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001     40.900749           0.818182      95.40              0.00
# C10002   3202.467416           0.909091       0.00              0.00
# C10003   2495.148862           1.000000     773.17            773.17
# C10004   1666.670542           0.636364    1499.00           1499.00
# C10005    817.714335           1.000000      16.00             16.00
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                     95.4      0.000000             0.166667
# C10002                      0.0   6442.945483             0.000000
# C10003                      0.0      0.000000             1.000000
# C10004                      0.0    205.788017             0.083333
# C10005                      0.0      0.000000             0.083333
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CUST_ID
# ...

# %%
#Cek baris dan kolom
df.shape
# Out:
# (8950, 17)

# %% [markdown]
# dataset terdiri dari 8950 baris dan 17 kolom

# %%
# Cek tipe data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8950 entries, C10001 to C19190
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
# ...

# %%
# Menampilkan deskripsi statistik
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# kita ketahui bahwa kolom2 kategorik memiliki nilai 0-1. Namun pada hal ini kolom2 kategorik berbentuk float (nilai tidak bulat 0 atau 1)

# %% [markdown]
# <hr>

# %% [markdown]
# ## 03| Exploratory Data Analysis

# %% [markdown]
# ### a. Checking and cleaning data

# %%
#Melihat missing value
df.isna().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#Drop missing value
df.dropna(inplace=True)

# %%
#Memastikan missing value
df.isna().sum().sum()
# Out:
# 0

# %%
#Cek data duplikat
df.duplicated().any()
# Out:
# False

# %% [markdown]
# Kemudian kita cek kolom kategorik yaitu semua kolom yang diakhiri 'FREQUENCY'.

# %%
df[['BALANCE_FREQUENCY','PURCHASES_FREQUENCY','ONEOFF_PURCHASES_FREQUENCY',
    'PURCHASES_INSTALLMENTS_FREQUENCY','CASH_ADVANCE_FREQUENCY']].max()
# Out:
# BALANCE_FREQUENCY                   1.0
# PURCHASES_FREQUENCY                 1.0
# ONEOFF_PURCHASES_FREQUENCY          1.0
# PURCHASES_INSTALLMENTS_FREQUENCY    1.0
# CASH_ADVANCE_FREQUENCY              1.5
# dtype: float64

# %% [markdown]
# kita akan treatment kolom2 untuk nilai max '1', akan kita bulatkan menggunakan fungsi round. sedangkan untuk yg max '1.5' kita buat range (0-0.5 = 0 ; 0.5-1.5 =1)

# %%
df.BALANCE_FREQUENCY = round(df.BALANCE_FREQUENCY).astype('int64')
df.PURCHASES_FREQUENCY = round(df.PURCHASES_FREQUENCY).astype('int64')
df.ONEOFF_PURCHASES_FREQUENCY = round(df.ONEOFF_PURCHASES_FREQUENCY).astype('int64')
df.PURCHASES_INSTALLMENTS_FREQUENCY = round(df.PURCHASES_INSTALLMENTS_FREQUENCY).astype('int64')

# %%
df.CASH_ADVANCE_FREQUENCY = [1 if i > 0.5 else 0 for i in df.CASH_ADVANCE_FREQUENCY]

# %%
data_cat = ['BALANCE_FREQUENCY','PURCHASES_FREQUENCY','ONEOFF_PURCHASES_FREQUENCY',
            'PURCHASES_INSTALLMENTS_FREQUENCY','CASH_ADVANCE_FREQUENCY']

for i in data_cat:
    print('-'*50)
    print(df[i].value_counts())
# Out:
# --------------------------------------------------
# 1    7892
# 0     744
# Name: BALANCE_FREQUENCY, dtype: int64
# --------------------------------------------------
# 0    4575
# 1    4061
# Name: PURCHASES_FREQUENCY, dtype: int64
# --------------------------------------------------
# 0    7311
# 1    1325
# Name: ONEOFF_PURCHASES_FREQUENCY, dtype: int64
# --------------------------------------------------
# 0    5613
# 1    3023
# Name: PURCHASES_INSTALLMENTS_FREQUENCY, dtype: int64
# --------------------------------------------------
# 0    8105
# 1     531
# Name: CASH_ADVANCE_FREQUENCY, dtype: int64

# %% [markdown]
# semua sudah menjadi 0 atau 1.

# %% [markdown]
# ### B. Visualisasi data

# %%
# Countplot dari kolom 'TENURE'
sns.countplot(df['TENURE'], palette='Set2')
# Out:
# <AxesSubplot:xlabel='TENURE', ylabel='count'>

# %% [markdown]
# Untuk kolom numerik, mari kita tampilkan histogramnya untuk melihat distribusi data.

# %%
plt.figure(figsize=(15,15))

for i in enumerate(df.describe().columns):
  plt.subplot(6,3, i[0]+1)
  sns.distplot(df[i[1]])
plt.tight_layout()
plt.show()

# %% [markdown]
# Sekarang kita tampilkan korelasi antarkolom dengan <i>heatmap</i>.

# %%
# Melihat outlier
fig, ax = plt.subplots(ncols=3, nrows=6, figsize=(13,20))
index = 0
ax = ax.flatten()

for col, value in df.items():
    sns.boxplot(x=col, data=df, color='lightblue', ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %%
# Menampilkan korelasi antarkolom dengan heatmap

plt.figure(figsize=(12,7))

corr = df.corr()
sns.heatmap(corr, annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <hr>

# %% [markdown]
# ## 04| Preprocessing Data

# %%
df.head()
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001     40.900749                  1      95.40              0.00
# C10002   3202.467416                  1       0.00              0.00
# C10003   2495.148862                  1     773.17            773.17
# C10005    817.714335                  1      16.00             16.00
# C10006   1809.828751                  1    1333.28              0.00
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                    95.40      0.000000                    0
# C10002                     0.00   6442.945483                    0
# C10003                     0.00      0.000000                    1
# C10005                     0.00      0.000000                    0
# C10006                  1333.28      0.000000                    1
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CUST_ID
# ...

# %%
#Kolom numerik
df_num = df[[
             'BALANCE','PURCHASES', 'ONEOFF_PURCHASES','INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
             'CASH_ADVANCE_TRX', 'PURCHASES_TRX','CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 
             'PRC_FULL_PAYMENT','TENURE'
            ]]

#Kolom kategorik
df_cat = df[['BALANCE_FREQUENCY','PURCHASES_FREQUENCY','ONEOFF_PURCHASES_FREQUENCY',
            'PURCHASES_INSTALLMENTS_FREQUENCY','CASH_ADVANCE_FREQUENCY']]

# %% [markdown]
# Kemudian kita lakukan scaling menggunakan minmax scaler untuk dataframe <code>df_new</code>.

# %%
from sklearn.preprocessing import MinMaxScaler

df_norm = MinMaxScaler().fit_transform(df_num)
df_norm = pd.DataFrame(df_norm,columns=df_num.columns, index=df_num.index)
df_norm.head()
# Out:
#           BALANCE  PURCHASES  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# CUST_ID
# C10001   0.002148   0.001945          0.000000                0.004240
# C10002   0.168169   0.000000          0.000000                0.000000
# C10003   0.131026   0.015766          0.018968                0.000000
# C10005   0.042940   0.000326          0.000393                0.000000
# C10006   0.095038   0.027188          0.000000                0.059257
#
#          CASH_ADVANCE  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# CUST_ID
# C10001       0.000000           0.00000       0.005587      0.031720
# C10002       0.136685           0.03252       0.000000      0.232053
# C10003       0.000000           0.00000       0.033520      0.248748
# C10005       0.000000           0.00000       0.002793      0.038397
# C10006       0.000000           0.00000       0.022346      0.058431
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# CUST_ID
# ...

# %%
df_new = pd.concat([df_norm,df_cat], axis=1)
df_new.head(5)
# Out:
#           BALANCE  PURCHASES  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# CUST_ID
# C10001   0.002148   0.001945          0.000000                0.004240
# C10002   0.168169   0.000000          0.000000                0.000000
# C10003   0.131026   0.015766          0.018968                0.000000
# C10005   0.042940   0.000326          0.000393                0.000000
# C10006   0.095038   0.027188          0.000000                0.059257
#
#          CASH_ADVANCE  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# CUST_ID
# C10001       0.000000           0.00000       0.005587      0.031720
# C10002       0.136685           0.03252       0.000000      0.232053
# C10003       0.000000           0.00000       0.033520      0.248748
# C10005       0.000000           0.00000       0.002793      0.038397
# C10006       0.000000           0.00000       0.022346      0.058431
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  \
# CUST_ID
# ...

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

print('The Silhouette Score to find the No. of Optimal Clusters')
Elbow_M = KElbowVisualizer(KMeans(random_state=123), k=10, metric='silhouette')
Elbow_M.fit(df_new)
Elbow_M.show()
# Out:
# The Silhouette Score to find the No. of Optimal Clusters
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %% [markdown]
# <hr>

# %% [markdown]
# ## 05| Modeling Data

# %%
clusterNum = 3

k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(df_new)
# Out:
# KMeans(n_clusters=3, n_init=12)

# %% [markdown]
# Setelah pemodelan, kita dapat menampilkan label klaster dengan atribut <code>.labels_</code>.

# %%
# Menampilkan label klaster
k_means_labels = k_means.labels_
k_means_labels
# Out:
# array([0, 0, 2, ..., 1, 0, 2])

# %% [markdown]
# Kemudian, kita dapat menampilkan <i>cluster center</i> dengan atribut <code>.cluster_centers_</code>. Outputnya adalah berupa array (n_cluster, n_features).

# %%
# Menampilkan cluster centers

k_means_cluster_centers = k_means.cluster_centers_
k_means_cluster_centers
# Out:
# array([[ 9.09833264e-02,  6.19784253e-03,  5.61485269e-03,
#          3.34516703e-03,  2.84528908e-02,  3.54452365e-02,
#          7.83318812e-03,  1.37034550e-01,  2.98896562e-02,
#          1.10704280e-02,  8.27306999e-02,  9.16375419e-01,
#          8.56050677e-01,  6.55307995e-04, -1.63757896e-15,
#         -3.38618023e-15,  8.21319353e-02],
#        [ 6.46011928e-02,  2.32028258e-02,  8.14694683e-03,
#          3.58414677e-02,  1.25193295e-02,  1.67391026e-02,
#          5.94584705e-02,  1.34432775e-01,  2.95242161e-02,
#          1.23956723e-02,  2.30278532e-01,  9.17428955e-01,
#          9.71094036e-01,  1.00000000e+00, -1.47104551e-15,
#          8.69008416e-01,  3.40285401e-02],
#        [ 1.00432781e-01,  6.70148027e-02,  6.05198412e-02,
#          3.64227881e-02,  1.33358908e-02,  1.86102163e-02,
#          1.23988616e-01,  2.22465046e-01,  6.51307295e-02,
#          9.90963320e-03,  2.77474515e-01,  9.53459119e-01,
# ...

# %%
# Memasukkan label ke dalam dataframe
df['Cluster'] = k_means_labels
df.head()
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001     40.900749                  1      95.40              0.00
# C10002   3202.467416                  1       0.00              0.00
# C10003   2495.148862                  1     773.17            773.17
# C10005    817.714335                  1      16.00             16.00
# C10006   1809.828751                  1    1333.28              0.00
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                    95.40      0.000000                    0
# C10002                     0.00   6442.945483                    0
# C10003                     0.00      0.000000                    1
# C10005                     0.00      0.000000                    0
# C10006                  1333.28      0.000000                    1
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CUST_ID
# ...

# %% [markdown]
# Selanjutnya mari kita cek jumlah data pada masing-masing klaster.

# %%
# Jumlah data pada tiap klaster
df['Cluster'].value_counts()
# Out:
# 0    4578
# 1    2733
# 2    1325
# Name: Cluster, dtype: int64

# %% [markdown]
# <hr>

# %% [markdown]
# ## 06| Insight

# %%
# visualisasi klaster
plt.figure(figsize=(15,8))

sns.scatterplot(df.BALANCE, df.PAYMENTS, hue=df.Cluster, palette='Set2', sizes=5000)

plt.legend()
plt.xlabel('BALANCE')
plt.ylabel('PAYMENTS')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(df.Cluster, df.PAYMENTS)
plt.subplot(1,2,2)
sns.boxplot(df.Cluster, df.BALANCE)

plt.suptitle('Payments and Balance')
plt.tight_layout()
plt.show()

# %%
# Mengecek centroid
df.groupby('Cluster').mean()
# Out:
#              BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# Cluster
# 0        1732.608092           0.856051   303.939533        228.868414
# 1        1230.209466           0.971094  1137.856601        332.079737
# 2        1912.555364           0.995472  3286.377109       2466.864377
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# Cluster
# 0                     75.266258   1341.189940             0.000655
# 1                    806.433022    590.126284             1.000000
# 2                    819.512732    628.616709             1.000000
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# Cluster
# 0                               0.0                          0.000000
# 1                               0.0                          0.869008
# 2                               1.0                          0.489057
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# Cluster
# ...

# %% [markdown]
# Dari hasil di atas, dapat kita simpulkan untuk masing-masing klaster (0, 1, dan 2)
#
# * __Klaster 0 (Biru) :__ payments sedang, balance sedang
# * __Klaster 1 (Merah) :__ payments rendah, balance rendah
# * __Klaster 2 (Hijau) :__ payment tinggi, balance tinggi

# %% [markdown]
# by: muhamadsahri08@gmail.com
